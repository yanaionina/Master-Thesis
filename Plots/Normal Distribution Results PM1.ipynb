# %% [markdown]
# # Normal Distribution Results of Process Model 1

# %%
from scipy import stats
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas
import seaborn
import seaborn as sns, numpy as np
import numpy as np
import pylab as pl


fig, ax = plt.subplots(1, 2, figsize=(7,3))
df = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/process with evolution/Data/regionres2.xlsx'))
data = sorted(df['Conf'])
std = np.std(data)
mean = np.mean(data) 
fit = stats.norm.pdf(data, np.mean(data), np.std(data))
a = ax[0].plot(data,fit, linewidth=2)
ax[0].hist(data)
ax[0].set_title('Region-based approach', fontsize=10)
ax[0].set_xlabel('Avarage Conformance', fontsize=12)
ax[0].set_ylabel('Frequency (cases)', fontsize=12)


df = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/process with evolution/Data/behavres.xlsx'))
data2 = sorted(df['Conformance'])
std2 = np.std(data2)
mean2 = np.mean(data2) 
fit2 = stats.norm.pdf(data2, np.mean(data2), np.std(data2))
b = ax[1].plot(data2,fit2, linewidth=2)
ax[1].hist(data2)
ax[1].set_title('Behavioural Patterns approach', fontsize=10)
ax[1].set_xlabel('Avarage Conformance', fontsize=12)
ax[1].set_ylabel('Frequency (cases)', fontsize=12)
#plt.legend(loc='best')
plt.tight_layout()
plt.show(a) 
plt.show(b)


print('Standard deviation of Region-based:', round(std, 3), 
    ', Mean:', round(mean, 3))
print('Standard deviation of Behavioural Patterns:', round(std2, 3), 
    ', Mean:', round(mean2, 3))
# Out:
# Standard deviation of Region-based: 0.267 , Mean: 0.863
# Standard deviation of Behavioural Patterns: 0.294 , Mean: 0.852

# %%
from scipy import stats
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas
import seaborn
import seaborn as sns, numpy as np
import numpy as np
import pylab as pl


fig, ax = plt.subplots(2, 3, figsize=(13,6))

df = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/process with evolution/Data/soft02varres.xlsx'))
data = sorted(df['Conformance'])

#fig, ax = plt.subplots(figsize=(4,3))
std = np.std(data)
mean = np.mean(data) 
fit = stats.norm.pdf(data, np.mean(data), np.std(data))
a = ax[0,0].plot(data,fit, linewidth=2)
ax[0,0].hist(data)
ax[0,0].set_title('Soft Conformance with weight 0.2 (on variants)', fontsize=10)
ax[0,0].set_xlabel('Avarage Conformance', fontsize=12)
ax[0,0].set_ylabel('Frequency (cases)', fontsize=12)
#plt.legend(loc='best')
plt.tight_layout()
#plt.show() 


df1 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/process with evolution/Data/Soft w 05.var.xlsx'))
data1 = sorted(df1['Conformance'])
std1 = np.std(data1)
mean1 = np.mean(data1) 
fit1 = stats.norm.pdf(data1, np.mean(data1), np.std(data1))
b = ax[0,1].plot(data1,fit1, linewidth=2)
ax[0,1].hist(data1)
ax[0,1].set_title('Soft Conformance with weight 0.5 (on variants)', fontsize=10)
ax[0,1].set_xlabel('Avarage Conformance', fontsize=12)
ax[0,1].set_ylabel('Frequency (cases)', fontsize=12)
#plt.legend(loc='best')
plt.tight_layout()

df2 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/process with evolution/Data/Soft w 09.var.xlsx'))
data2 = sorted(df2['Conformance'])
std2 = np.std(data2)
mean2 = np.mean(data2) 
fit2 = stats.norm.pdf(data2, np.mean(data2), np.std(data2))
c = ax[0,2].plot(data2,fit2, linewidth=2)
ax[0,2].hist(data2)
ax[0,2].set_title('Soft Conformance with weight 0.9 (on variants)', fontsize=10)
ax[0,2].set_xlabel('Avarage Conformance', fontsize=12)
ax[0,2].set_ylabel('Frequency (cases)', fontsize=12)
#plt.legend(loc='best')
plt.tight_layout()


df3 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/process with evolution/Data/Soft w 02.trdistr.xlsx'))
data3 = sorted(df3['Conformance'])
std3 = np.std(data3)
mean3 = np.mean(data3) 
fit3 = stats.norm.pdf(data3, np.mean(data3), np.std(data3))
d = ax[1,0].plot(data3,fit3, linewidth=2)
ax[1,0].hist(data3)
ax[1,0].set_title('Soft Conformance with weight 0.2 (on test)', fontsize=10)
ax[1,0].set_xlabel('Avarage Conformance', fontsize=12)
ax[1,0].set_ylabel('Frequency (cases)', fontsize=12)
#plt.legend(loc='best')
plt.tight_layout()


df4 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/process with evolution/Data/Soft 05.tr distr.xlsx'))
data4 = sorted(df4['Conformance'])
std4 = np.std(data4)
mean4 = np.mean(data4) 
fit4 = stats.norm.pdf(data4, np.mean(data4), np.std(data4))
e = ax[1,1].plot(data4,fit4, linewidth=2)
ax[1,1].hist(data4)
ax[1,1].set_title('Soft Conformance with weight 0.5 (on test)', fontsize=10)
ax[1,1].set_xlabel('Avarage Conformance', fontsize=12)
ax[1,1].set_ylabel('Frequency (cases)', fontsize=12)
#plt.legend(loc='best')
plt.tight_layout()

df5 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/process with evolution/Data/Soft 09.tr distr.xlsx'))
data5 = sorted(df5['Conformance'])
std5 = np.std(data5)
mean5 = np.mean(data5) 
fit5 = stats.norm.pdf(data5, np.mean(data5), np.std(data5))
f = ax[1,2].plot(data5,fit5, linewidth=2)
ax[1,2].hist(data5)
ax[1,2].set_title('Soft Conformance with weight 09 (on test)', fontsize=10)
ax[1,2].set_xlabel('Avarage Conformance', fontsize=12)
ax[1,2].set_ylabel('Frequency (cases)', fontsize=12)
#plt.legend(loc='best')
plt.tight_layout()

plt.show(a) 
plt.show(b)
plt.show(c)
plt.show(d)
plt.show(e)
plt.show(f)



print('Standard deviation of Soft Conformance with weight 0.2 (on variants):', round(std, 3), 
    ', Mean:', round(mean, 3))
print('Standard deviation of Soft Conformance with weight 0.5 (on variants):', round(std1, 3), 
    ', Mean:', round(mean1, 3))
print('Standard deviation of Soft Conformance with weight 0.9 (on variants):', round(std2, 3), 
    ', Mean:', round(mean2, 3))
print('Standard deviation of Soft Conformance with weight 0.2 (on test):', round(std3, 3), 
    ', Mean:', round(mean3, 3))
print('Standard deviation of Soft Conformance with weight 0.5 (on test):', round(std4, 3), 
    ', Mean:', round(mean4, 3))
print('Standard deviation of Soft Conformance with weight 0.9 (on test):', round(std5, 3), 
    ', Mean:', round(mean5, 3))
# Out:
# Standard deviation of Soft Conformance with weight 0.2 (on variants): 0.239 , Mean: 0.702
# Standard deviation of Soft Conformance with weight 0.5 (on variants): 0.23 , Mean: 0.666
# Standard deviation of Soft Conformance with weight 0.9 (on variants): 0.223 , Mean: 0.652
# Standard deviation of Soft Conformance with weight 0.2 (on test): 0.217 , Mean: 0.721
# Standard deviation of Soft Conformance with weight 0.5 (on test): 0.201 , Mean: 0.672
# Standard deviation of Soft Conformance with weight 0.9 (on test): 0.211 , Mean: 0.683
