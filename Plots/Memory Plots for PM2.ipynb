# %% [markdown]
# # Memory consumption for Process Model 2

# %%
import pandas as pd
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from matplotlib import dates as mpl_dates
import matplotlib.pyplot as plt

fig, ax = plt.subplots(8, 1, figsize=(45,65))

df = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/Generated process model 3/Data/Region mem.xlsx'))
data1 = df['Time']
data2 = df['Memory']
data = df['Traces']
ax2 = ax[0].twinx()
ax[0].set_title('Traces distribution and Memory consumption over the time (Region-based)', fontsize=15)
ax[0].set_xlabel('Time interval ''(in sec)', fontsize=10)
a = ax[0].plot(df['Time'], df['Memory'], color='green', marker='o', linewidth=3, markersize=10)
b = ax2.plot(df['Time'], df['Traces'], color='red', marker='x', linewidth=3, markersize=10)

for index in range(len(data1)):
    ax[0].text(data1[index], data2[index], data2[index], color="blue",  size=12, verticalalignment='top')

for index in range(len(data1)):
    ax2.text(data1[index], data[index], data[index], size=12, verticalalignment='bottom')
ax[0].set_ylabel('Memory (in MB)', fontsize=10)
ax2.set_ylabel('Traces', fontsize=10)
for xlabel in ax[0].get_xticklabels():
    xlabel.set_rotation(60)
ax[0].legend(['Memory'], loc='upper left',fontsize=10)
ax2.legend(['Traces'], loc='center left', fontsize=10)
ax[0].yaxis.grid(color='lightgray', linestyle='dashed')



df1 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/Generated process model 3/Data/Behav mem.xlsx'))

data4 = df1['Memory']
data5 = df1['Traces']
ax2 = ax[1].twinx()
ax[1].set_title('Traces distribution and Memory consumption over the time (Behavioural Patterns)', fontsize=15)
ax[1].set_xlabel('Time interval ''(in sec)', fontsize=10)
c = ax[1].plot(df['Time'], df1['Memory'], color='green', marker='o', linewidth=3, markersize=10)
d = ax2.plot(df['Time'], df1['Traces'], color='red', marker='x', linewidth=3, markersize=10)

for index in range(len(data1)):
    ax[1].text(data1[index], data4[index], data4[index], color="blue",  size=12, verticalalignment='top')

for index in range(len(data1)):
    ax2.text(data1[index], data5[index], data5[index], size=12, verticalalignment='bottom')
ax[1].set_ylabel('Memory (in MB)', fontsize=10)
ax2.set_ylabel('Traces', fontsize=10)
for xlabel in ax[1].get_xticklabels():
    xlabel.set_rotation(60)
ax[1].legend(['Memory'], loc='upper left',fontsize=10)
ax2.legend(['Traces'], loc='center left', fontsize=10)


ax[1].yaxis.grid(color='lightgray', linestyle='dashed')



df2 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/Generated process model 3/Data/soft02varmem.xlsx'))

data7 = df2['Memory']
data8 = df2['Traces']
ax2 = ax[2].twinx()
ax[2].set_title('Traces distribution and Memory consumption over the time (Soft Conformance weight 0.2 (variants filtering))', fontsize=15)
ax[2].set_xlabel('Time interval ''(in sec)', fontsize=10)
e = ax[2].plot(df['Time'], df2['Memory'], color='green', marker='o', linewidth=3, markersize=10)
f = ax2.plot(df['Time'], df2['Traces'], color='red', marker='x', linewidth=3, markersize=10)

for index in range(len(data1)):
    ax[2].text(data1[index], data7[index], data7[index], color="blue",  size=12, verticalalignment='top')

for index in range(len(data1)):
    ax2.text(data1[index], data8[index], data8[index], size=12, verticalalignment='bottom')
ax[2].set_ylabel('Memory (in MB)', fontsize=10)
ax2.set_ylabel('Traces', fontsize=10)
for xlabel in ax[2].get_xticklabels():
    xlabel.set_rotation(60)
ax[2].legend(['Memory'], loc='upper left',fontsize=10)
ax2.legend(['Traces'], loc='center left', fontsize=10)
ax[2].yaxis.grid(color='lightgray', linestyle='dashed')



df3 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/Generated process model 3/Data/Soft05f mem.xlsx'))

data10 = df3['Memory']
data11 = df3['Traces']
ax2 = ax[3].twinx()
ax[3].set_title('Traces distribution and Memory consumption over the time (Soft Conformance weight 0.5 (variants filtering))', fontsize=15)
ax[3].set_xlabel('Time interval ''(in sec)', fontsize=10)
g = ax[3].plot(df['Time'], df3['Memory'], color='green', marker='o', linewidth=3, markersize=10)
h = ax2.plot(df['Time'], df3['Traces'], color='red', marker='x', linewidth=3, markersize=10)

for index in range(len(data1)):
    ax[3].text(data1[index], data10[index], data10[index], color="blue",  size=12, verticalalignment='top')

for index in range(len(data1)):
    ax2.text(data1[index], data11[index], data11[index], size=12, verticalalignment='bottom')
ax[3].set_ylabel('Memory (in MB)', fontsize=10)
ax2.set_ylabel('Traces', fontsize=10)
for xlabel in ax[3].get_xticklabels():
    xlabel.set_rotation(60)
ax[3].legend(['Memory'], loc='upper left',fontsize=10)
ax2.legend(['Traces'], loc='center left', fontsize=10)


ax[3].yaxis.grid(color='lightgray', linestyle='dashed')


df4 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/Generated process model 3/Data/Soft09var mem.xlsx'))

data13 = df4['Memory']
data14 = df4['Traces']
ax2 = ax[4].twinx()
ax[4].set_title('Traces distribution and Memory consumption over the time (Soft Conformance weight 0.9 (variants filtering))', fontsize=15)
ax[4].set_xlabel('Time interval ''(in sec)', fontsize=10)
i = ax[4].plot(df['Time'], df4['Memory'], color='green', marker='o', linewidth=3, markersize=10)
j = ax2.plot(df['Time'], df4['Traces'], color='red', marker='x', linewidth=3, markersize=10)

for index in range(len(data1)):
    ax[4].text(data1[index], data13[index], data13[index], color="blue",  size=12, verticalalignment='top')

for index in range(len(data1)):
    ax2.text(data1[index], data14[index], data14[index], size=12, verticalalignment='bottom')
ax[4].set_ylabel('Memory (in MB)', fontsize=10)
ax2.set_ylabel('Traces', fontsize=10)
for xlabel in ax[4].get_xticklabels():
    xlabel.set_rotation(60)
ax[4].legend(['Memory'], loc='upper left',fontsize=10)
ax2.legend(['Traces'], loc='center left', fontsize=10)
ax[4].yaxis.grid(color='lightgray', linestyle='dashed')

df5 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/Generated process model 3/Data/Soft02trainmem.xlsx'))

data16 = df5['Memory']
data17 = df5['Traces']
ax2 = ax[5].twinx()
ax[5].set_title('Traces distribution and Memory consumption over the time (Soft Conformance weight 0.2 (test set))', fontsize=15)
ax[5].set_xlabel('Time interval ''(in sec)', fontsize=10)
k = ax[5].plot(df['Time'], df5['Memory'], color='green', marker='o', linewidth=3, markersize=10)
l = ax2.plot(df['Time'], df5['Traces'], color='red', marker='x', linewidth=3, markersize=10)

for index in range(len(data1)):
    ax[5].text(data1[index], data16[index], data16[index], color="blue",  size=12, verticalalignment='top')

for index in range(len(data1)):
    ax2.text(data1[index], data17[index], data17[index], size=12, verticalalignment='bottom')
ax[5].set_ylabel('Memory (in MB)', fontsize=10)
ax2.set_ylabel('Traces', fontsize=10)
for xlabel in ax[5].get_xticklabels():
    xlabel.set_rotation(60)
ax[5].legend(['Memory'], loc='upper left',fontsize=10)
ax2.legend(['Traces'], loc='center left', fontsize=10)


ax[5].yaxis.grid(color='lightgray', linestyle='dashed')
plt.tight_layout()

df6 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/Generated process model 3/Data/Soft05trainmem.xlsx'))

data19 = df6['Memory']
data20 = df6['Traces']
ax2 = ax[6].twinx()
ax[6].set_title('Traces distribution and Memory consumption over the time (Soft Conformance weight 0.5 (test set))', fontsize=15)
ax[6].set_xlabel('Time interval ''(in sec)', fontsize=10)
m = ax[6].plot(df['Time'], df6['Memory'], color='green', marker='o', linewidth=3, markersize=10)
n = ax2.plot(df['Time'], df6['Traces'], color='red', marker='x', linewidth=3, markersize=10)

for index in range(len(data1)):
    ax[6].text(data1[index], data19[index], data19[index], color="blue",  size=12, verticalalignment='top')

for index in range(len(data1)):
    ax2.text(data1[index], data20[index], data20[index], size=12, verticalalignment='bottom')
ax[6].set_ylabel('Memory (in MB)', fontsize=10)
ax2.set_ylabel('Traces', fontsize=10)
for xlabel in ax[6].get_xticklabels():
    xlabel.set_rotation(60)
ax[6].legend(['Memory'], loc='upper left',fontsize=10)
ax2.legend(['Traces'], loc='center left', fontsize=10)


ax[6].yaxis.grid(color='lightgray', linestyle='dashed')
plt.tight_layout()



df7 = pd.DataFrame(pd.read_excel('C:/Users/I559643/Documents/Thesis/Models and Logs/Generated process model 3/Data/Soft09trainmem.xlsx'))

data22 = df7['Memory']
data23 = df7['Traces']
ax2 = ax[7].twinx()
ax[7].set_title('Traces distribution and Memory consumption over the time (Soft Conformance weight 0.9 (test set))', fontsize=15)
ax[7].set_xlabel('Time interval ''(in sec)', fontsize=10)
o = ax[7].plot(df['Time'], df7['Memory'], color='green', marker='o', linewidth=3, markersize=10)
p = ax2.plot(df['Time'], df7['Traces'], color='red', marker='x', linewidth=3, markersize=10)

for index in range(len(data1)):
    ax[7].text(data1[index], data22[index], data22[index], color="blue",  size=12, verticalalignment='top')

for index in range(len(data1)):
    ax2.text(data1[index], data23[index], data23[index], size=12, verticalalignment='bottom')
ax[7].set_ylabel('Memory (in MB)', fontsize=10)
ax2.set_ylabel('Traces', fontsize=10)
for xlabel in ax[7].get_xticklabels():
    xlabel.set_rotation(60)
ax[7].legend(['Memory'], loc='upper left',fontsize=10)
ax2.legend(['Traces'], loc='center left', fontsize=10)

ax[7].yaxis.grid(color='lightgray', linestyle='dashed')




plt.show(a)
plt.show(b)
mean = np.mean(data2)
print(round(mean, 2))
plt.show(c)
plt.show(d)
mean = np.mean(data4)
print(round(mean, 2))
plt.show(e)
plt.show(f)
mean = np.mean(data7)
print(round(mean, 2))
plt.show(g)
plt.show(h)
mean = np.mean(data10)
print(round(mean, 2))
plt.show(i)
plt.show(j)
mean = np.mean(data13)
print(round(mean, 2))
plt.show(k)
plt.show(l)
mean = np.mean(data16)
print(round(mean, 2))
plt.show(m)
plt.show(n)
mean = np.mean(data19)
print(round(mean, 2))
plt.show(o)
plt.show(p)
mean = np.mean(data22)
print(round(mean, 2))
# Out:
# 610.55
# 608.21
# 523.87
# 759.34
# 530.26
# 601.61
# 613.95
# 554.98
